# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rarfile
import rarfile

filename = "/content/drive/MyDrive/Colab_Notebooks/DRIVE_Augmented.rar"

# Use the RarFile class from the rarfile library
with rarfile.RarFile(filename, 'r') as rar:
    rar.extractall()
    print('Done')
# Out:
# Collecting rarfile
#   Downloading rarfile-4.0-py3-none-any.whl (28 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.0
# Done

# %%
import os
# !pip install Keras-Preprocessing
import tensorflow as tf
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split
import imageio

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout, Resizing
from keras.layers import Lambda, RepeatVector, Reshape
from keras.layers import Conv2D, Conv2DTranspose
from keras.layers import MaxPooling2D, GlobalMaxPool2D, AveragePooling2D
from keras.regularizers import l2
#from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras_preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import *
from keras.losses import *
from keras import backend as keras

from keras.utils import plot_model

from keras.preprocessing.image import ImageDataGenerator
import cv2
import skimage.io as io

import glob
from PIL import Image
import skimage
from keras.initializers import Constant

from skimage.morphology import disk
from sklearn.metrics import confusion_matrix
from skimage.measure import label, regionprops
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import jaccard_score

from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras import layers, models
import zipfile
import random
import sys

import skimage.io                           #Used for imshow function
import skimage.transform                    #Used for resize function
from skimage.morphology import label        #Used for Run-Length-Encoding RLE to create final submission
import matplotlib.pyplot as plt
from keras.layers import Concatenate, add

import warnings
warnings.filterwarnings("ignore")
random.seed(42)
from keras.losses import binary_crossentropy
from sklearn.metrics import precision_recall_curve
# Out:
# Collecting Keras-Preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.23.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from Keras-Preprocessing) (1.16.0)
# Installing collected packages: Keras-Preprocessing
# Successfully installed Keras-Preprocessing-1.1.2

# %%
dataset_dir = '/content/drive/MyDrive/Colab_Notebooks/DRIVE_Augmented/DRIVE_BioNet-Augmented'
os.listdir(dataset_dir)
# Out:
# ['test', 'train', 'train2']

# %%
from keras import backend as K

from scipy.ndimage import distance_transform_edt as distance
from keras.losses import binary_crossentropy
def dice_coef(y_true, y_pred,smooth = 10):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def Jaccard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection ) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection)

def Jaccard_coef_loss(y_true, y_pred):
    return (1-Jaccard_coef(y_true, y_pred))

# def bcc_Jaccard_coef_loss(y_true, y_pred):
#     return (binary_crossentropy(y_true, y_pred)+(1-Jaccard_coef(y_true, y_pred)))

#Metrices
from keras import backend as K
import tensorflow as tf
import keras

def iou(y_true, y_pred, threshold=0.5):
    y_pred = threshold_binarize(y_pred, threshold)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection)

def dice_coef(y_true, y_pred, threshold=0.5):
    y_pred = threshold_binarize(y_pred, threshold)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))

def sensitivity(y_train, results):
    true_positives = K.sum(K.round(K.clip(y_train * results, 0, 1)))
    actual_positives = K.sum(K.round(K.clip(y_train, 0, 1)))
    sensitivity = true_positives / (actual_positives + K.epsilon())
    return sensitivity

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def threshold_binarize(x, threshold=0.5):
    ge = tf.greater_equal(x, tf.constant(threshold))
    y = tf.where(ge, x=tf.ones_like(x), y=tf.zeros_like(x))
    return y

def DiceLoss(y_true, y_pred, smooth=1e-6):
    y_true, y_pred = tf.cast(y_true, dtype=tf.float32), tf.cast(y_pred, tf.float32)
    nominator = 2 * tf.reduce_sum(tf.multiply(y_pred, y_true)) + smooth
    denominator = tf.reduce_sum(y_pred ** 2) + tf.reduce_sum(y_true ** 2) + smooth
    result = 1 - tf.divide(nominator, denominator)
    return result



def bcc_Jaccard_coef_loss(y_true, y_pred):
    return (DiceLoss(y_true, y_pred, smooth=1e-6)+(1-iou(y_true, y_pred, threshold=0.5)))

# %%
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate
from keras import backend as K

def cbam_block(cbam_feature, ratio=8):
    """Contains the implementation of Convolutional Block Attention Module(CBAM) block.
    As described in https://arxiv.org/abs/1807.06521.
    """

    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature.shape[channel_axis]

    shared_layer_one = Dense(channel//ratio,
                             activation='relu',
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    shared_layer_two = Dense(channel,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')

    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = Reshape((1,1,channel))(avg_pool)
    assert avg_pool.shape[1:] == (1,1,channel)
    avg_pool = shared_layer_one(avg_pool)
    assert avg_pool.shape[1:] == (1,1,channel//ratio)
    avg_pool = shared_layer_two(avg_pool)
    assert avg_pool.shape[1:] == (1,1,channel)

    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    assert max_pool.shape[1:] == (1,1,channel)
    max_pool = shared_layer_one(max_pool)
    assert max_pool.shape[1:] == (1,1,channel//ratio)
    max_pool = shared_layer_two(max_pool)
    assert max_pool.shape[1:] == (1,1,channel)

    cbam_feature = Add()([avg_pool,max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7

    if K.image_data_format() == "channels_first":
        channel = input_feature.shape[1]
        cbam_feature = Permute((2,3,1))(input_feature)
    else:
        channel = input_feature.shape[-1]
        cbam_feature = input_feature

    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    assert avg_pool.shape[-1] == 1
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    assert max_pool.shape[-1] == 1
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    assert concat.shape[-1] == 2
    cbam_feature = Conv2D(filters = 1,
                    kernel_size=kernel_size,
                    strides=1,
                    padding='same',
                    activation='sigmoid',
                    kernel_initializer='he_normal',
                    use_bias=False)(concat)
    assert cbam_feature.shape[-1] == 1

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

def create_transfuse_net(input_shape):
    # Define the input layer
    inputs = layers.Input(shape=input_shape)

    # Encoder - Convolutional Blocks
    conv_block1 = layers.Conv2D(8, kernel_size=(3, 3), padding='same', activation='relu')(inputs)
    conv_block1 = layers.MaxPooling2D(pool_size=(2, 2))(conv_block1)
    conv_block1 = layers.BatchNormalization()(conv_block1)

    conv_block2 = layers.Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu')(conv_block1)
    conv_block2 = layers.MaxPooling2D(pool_size=(2, 2))(conv_block2)
    conv_block2 = layers.BatchNormalization()(conv_block2)

    conv_block3 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(conv_block2)
    conv_block3 = layers.MaxPooling2D(pool_size=(2, 2))(conv_block3)
    conv_block3 = layers.BatchNormalization()(conv_block3)

    # Encoder - Transformer Block
    transformer_block = layers.Reshape((-1, conv_block3.shape[3]))(conv_block3)
    transformer_block = layers.MultiHeadAttention(num_heads=4, key_dim=32)(transformer_block, transformer_block)
    transformer_block = layers.GlobalAveragePooling1D()(transformer_block)
    transformer_block = layers.Reshape((1, 1, transformer_block.shape[1]))(transformer_block)

    # Tile the transformer block output to match the spatial dimensions of the convolutional block
    transformer_block = layers.Lambda(lambda x: tf.tile(x, [1, conv_block3.shape[1], conv_block3.shape[2], 1]))(transformer_block)

    # Concatenate the Encoder Convolutional and Transformer blocks

    att1 = cbam_block(transformer_block)
    fused_features = layers.Concatenate()([conv_block3, att1])

    # Decoder - Upsampling Blocks
    decoder_block1 = layers.Conv2DTranspose(32, kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu')(fused_features)
    att2=cbam_block(decoder_block1)
    decoder_block1 = layers.Concatenate()([att2, conv_block2])
    decoder_block1 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(decoder_block1)

    decoder_block2 = layers.Conv2DTranspose(16, kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu')(decoder_block1)

    att3=cbam_block(decoder_block2)
    decoder_block2 = layers.Concatenate()([att3, conv_block1])
    decoder_block2 = layers.Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu')(decoder_block2)


    decoder_block3 = layers.Conv2DTranspose(8, kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu')(decoder_block2)
    decoder_block3 = layers.Conv2D(8, kernel_size=(3, 3), padding='same', activation='relu')(decoder_block3)
    # Decoder - Output Block
    output_BV = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid',name = 'final_output1')(decoder_block3)
    output_OD = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid', name = 'final_output2')(decoder_block3)

    # Create the model
    model = models.Model(inputs=inputs, outputs=[output_BV, output_OD])

    return model

# Define the input shape for binary semantic segmentation
input_shape = (512,512,3)  # Example input shape for RGB images

# Create the TransFuse Encoder-Decoder model with 3 MaxPooling layers for binary semantic segmentation
model = create_transfuse_net(input_shape)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss={'final_output1': bcc_Jaccard_coef_loss, 'final_output2': bcc_Jaccard_coef_loss},
              metrics={'final_output1': [dice_coef, iou, sensitivity, specificity],
                       'final_output2': [dice_coef, iou, sensitivity, specificity]})

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 512, 512, 8)          224       ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 8)          0         ['conv2d[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 256, 256, 8)          32        ['max_pooling2d[0][0]']
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         1168      ['batch_normalization[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 16)         0         ['conv2d_1[0][0]']
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 16)         64        ['max_pooling2d_1[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 32)           0         ['conv2d_2[0][0]']
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 32)           128       ['max_pooling2d_2[0][0]']
#  chNormalization)
#
#  reshape (Reshape)           (None, 4096, 32)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  multi_head_attention (Mult  (None, 4096, 32)             16800     ['reshape[0][0]',
#  iHeadAttention)                                                     'reshape[0][0]']
#
#  global_average_pooling1d (  (None, 32)                   0         ['multi_head_attention[0][0]']
#  GlobalAveragePooling1D)
#
#  reshape_1 (Reshape)         (None, 1, 1, 32)             0         ['global_average_pooling1d[0][
#                                                                     0]']
#
#  lambda (Lambda)             (None, 64, 64, 32)           0         ['reshape_1[0][0]']
#
#  global_average_pooling2d (  (None, 32)                   0         ['lambda[0][0]']
#  GlobalAveragePooling2D)
#
#  global_max_pooling2d (Glob  (None, 32)                   0         ['lambda[0][0]']
#  alMaxPooling2D)
#
#  reshape_2 (Reshape)         (None, 1, 1, 32)             0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  reshape_3 (Reshape)         (None, 1, 1, 32)             0         ['global_max_pooling2d[0][0]']
#
#  dense (Dense)               (None, 1, 1, 4)              132       ['reshape_2[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  dense_1 (Dense)             (None, 1, 1, 32)             160       ['dense[0][0]',
#                                                                      'dense[1][0]']
#
#  add (Add)                   (None, 1, 1, 32)             0         ['dense_1[0][0]',
#                                                                      'dense_1[1][0]']
#
#  activation (Activation)     (None, 1, 1, 32)             0         ['add[0][0]']
#
#  multiply (Multiply)         (None, 64, 64, 32)           0         ['lambda[0][0]',
#                                                                      'activation[0][0]']
#
#  lambda_1 (Lambda)           (None, 64, 64, 1)            0         ['multiply[0][0]']
#
#  lambda_2 (Lambda)           (None, 64, 64, 1)            0         ['multiply[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 2)            0         ['lambda_1[0][0]',
#                                                                      'lambda_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 1)            98        ['concatenate[0][0]']
#
#  multiply_1 (Multiply)       (None, 64, 64, 32)           0         ['multiply[0][0]',
#                                                                      'conv2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 64)           0         ['batch_normalization_2[0][0]'
#  )                                                                  , 'multiply_1[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 128, 128, 32)         18464     ['concatenate_1[0][0]']
#  anspose)
#
#  global_average_pooling2d_1  (None, 32)                   0         ['conv2d_transpose[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_1 (Gl  (None, 32)                   0         ['conv2d_transpose[0][0]']
#  obalMaxPooling2D)
#
#  reshape_4 (Reshape)         (None, 1, 1, 32)             0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  reshape_5 (Reshape)         (None, 1, 1, 32)             0         ['global_max_pooling2d_1[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, 1, 1, 4)              132       ['reshape_4[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  dense_3 (Dense)             (None, 1, 1, 32)             160       ['dense_2[0][0]',
#                                                                      'dense_2[1][0]']
#
#  add_1 (Add)                 (None, 1, 1, 32)             0         ['dense_3[0][0]',
#                                                                      'dense_3[1][0]']
#
#  activation_1 (Activation)   (None, 1, 1, 32)             0         ['add_1[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 128, 32)         0         ['conv2d_transpose[0][0]',
#                                                                      'activation_1[0][0]']
#
#  lambda_3 (Lambda)           (None, 128, 128, 1)          0         ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)           (None, 128, 128, 1)          0         ['multiply_2[0][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 128, 2)          0         ['lambda_3[0][0]',
#  )                                                                   'lambda_4[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 1)          98        ['concatenate_2[0][0]']
#
#  multiply_3 (Multiply)       (None, 128, 128, 32)         0         ['multiply_2[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  concatenate_3 (Concatenate  (None, 128, 128, 48)         0         ['multiply_3[0][0]',
#  )                                                                   'batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)         13856     ['concatenate_3[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 256, 256, 16)         4624      ['conv2d_5[0][0]']
#  Transpose)
#
#  global_average_pooling2d_2  (None, 16)                   0         ['conv2d_transpose_1[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_2 (Gl  (None, 16)                   0         ['conv2d_transpose_1[0][0]']
#  obalMaxPooling2D)
#
#  reshape_6 (Reshape)         (None, 1, 1, 16)             0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  reshape_7 (Reshape)         (None, 1, 1, 16)             0         ['global_max_pooling2d_2[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1, 1, 2)              34        ['reshape_6[0][0]',
#                                                                      'reshape_7[0][0]']
#
#  dense_5 (Dense)             (None, 1, 1, 16)             48        ['dense_4[0][0]',
#                                                                      'dense_4[1][0]']
#
#  add_2 (Add)                 (None, 1, 1, 16)             0         ['dense_5[0][0]',
#                                                                      'dense_5[1][0]']
#
#  activation_2 (Activation)   (None, 1, 1, 16)             0         ['add_2[0][0]']
#
#  multiply_4 (Multiply)       (None, 256, 256, 16)         0         ['conv2d_transpose_1[0][0]',
#                                                                      'activation_2[0][0]']
#
#  lambda_5 (Lambda)           (None, 256, 256, 1)          0         ['multiply_4[0][0]']
#
#  lambda_6 (Lambda)           (None, 256, 256, 1)          0         ['multiply_4[0][0]']
#
#  concatenate_4 (Concatenate  (None, 256, 256, 2)          0         ['lambda_5[0][0]',
#  )                                                                   'lambda_6[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 1)          98        ['concatenate_4[0][0]']
#
#  multiply_5 (Multiply)       (None, 256, 256, 16)         0         ['multiply_4[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  concatenate_5 (Concatenate  (None, 256, 256, 24)         0         ['multiply_5[0][0]',
#  )                                                                   'batch_normalization[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 16)         3472      ['concatenate_5[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 512, 512, 8)          1160      ['conv2d_7[0][0]']
#  Transpose)
#
#  conv2d_8 (Conv2D)           (None, 512, 512, 8)          584       ['conv2d_transpose_2[0][0]']
#
#  final_output1 (Conv2D)      (None, 512, 512, 1)          9         ['conv2d_8[0][0]']
#
#  final_output2 (Conv2D)      (None, 512, 512, 1)          9         ['conv2d_8[0][0]']
#
# ==================================================================================================
# Total params: 66194 (258.57 KB)
# Trainable params: 66082 (258.13 KB)
# Non-trainable params: 112 (448.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir='TB',
    expand_nested=False,
    dpi=46,
    layer_range=None
)

# %%
train_data ='/content/DRIVE_Augmented/DRIVE_BioNet-Augmented/train' #data path
valid_data = '/content/DRIVE_Augmented/DRIVE_BioNet-Augmented/test'

# %%
import os
import numpy as np
im_height=512
im_width=512
# Get and resize train images and masks
def get_data(path):
    images_paths = os.path.join(path,'images')
    masks_path_BV = os.path.join(path,'GT_BV')
    masks_path_OD = os.path.join(path,'GT_OD')

    # images_ids = os.listdir(images_paths)
    # masks_ids = os.listdir(masks_paths)
    images_ids = sorted(os.listdir(images_paths))
    mask1_ids = sorted(os.listdir(masks_path_BV))
    mask2_ids = sorted(os.listdir(masks_path_OD))

    X = np.zeros((len(images_ids), im_height, im_width, 3), dtype=np.float32)
    y1 = np.zeros((len(mask1_ids), im_height, im_width, 1), dtype=np.float32)
    y2 = np.zeros((len(mask2_ids), im_height, im_width, 1), dtype=np.float32)
    print('Getting and resizing images ... ')
    for n in range (len(images_ids)):
        # Load images
        img = img_to_array(load_img(os.path.join(images_paths,images_ids[n]), grayscale=False))
        x_img = resize(img, (im_height, im_width, 3), mode='constant', preserve_range=True)

        # Load masks
        mask_BV = img_to_array(load_img(os.path.join(masks_path_BV,mask1_ids[n]), grayscale=True))
        mask_BV = resize( mask_BV, (im_height, im_width, 1), mode='constant', preserve_range=True)

        mask_OD = img_to_array(load_img(os.path.join(masks_path_OD, mask2_ids[n]), grayscale=True))
        mask_OD = resize(mask_OD, (im_height, im_width, 1), mode='constant', preserve_range=True)
        # Save images
        X[n] = x_img/ 255
        y1[n] = mask_BV/ 255
        y2[n] = mask_OD/255

    print('Done!')
    return X, [y1,y2]

# %%
X, [y1, y2] = get_data(train_data)  # get_data returns the input data and two output data sets

from sklearn.model_selection import train_test_split

# Split data for the BV task
X_train, X_test, y1_train_BV, y1_test_BV = train_test_split(X, y1, test_size=0.2, random_state=42)

# Split data for the OD task. Note: We use the same X_train and X_test for this task as well.
X_train, X_test, y2_train_od, y2_test_od = train_test_split(X, y2, test_size=0.2, random_state=42)
# Out:
# Getting and resizing images ...
# Done!

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
nb_epoch = 300
batch_size=8

checkpoint = ModelCheckpoint('/content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5', verbose=1, save_best_only=True,save_weights_only=True)
callbacks = [checkpoint]

# %%
results = model.fit(
    X_train,
    [y1_train_BV, y2_train_od],
    batch_size=batch_size,
    epochs=nb_epoch,
    callbacks=callbacks,
    validation_data=(X_test, [y1_test_BV, y2_test_od])
)
# Out:
# Epoch 1/300
# 40/40 [==============================] - ETA: 0s - loss: 3.4834 - final_output1_loss: 1.6409 - final_output2_loss: 1.8424 - final_output1_dice_coef: 0.0848 - final_output1_iou: 0.0457 - final_output1_sensitivity: 0.1024 - final_output1_specificity: 0.8192 - final_output2_dice_coef: 0.0117 - final_output2_iou: 0.0059 - final_output2_sensitivity: 0.0125 - final_output2_specificity: 0.9847
# Epoch 1: val_loss improved from inf to 3.53447, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 30s 218ms/step - loss: 3.4834 - final_output1_loss: 1.6409 - final_output2_loss: 1.8424 - final_output1_dice_coef: 0.0848 - final_output1_iou: 0.0457 - final_output1_sensitivity: 0.1024 - final_output1_specificity: 0.8192 - final_output2_dice_coef: 0.0117 - final_output2_iou: 0.0059 - final_output2_sensitivity: 0.0125 - final_output2_specificity: 0.9847 - val_loss: 3.5345 - val_final_output1_loss: 1.6906 - val_final_output2_loss: 1.8439 - val_final_output1_dice_coef: 2.4860e-06 - val_final_output1_iou: 1.2430e-06 - val_final_output1_sensitivity: 1.2529e-06 - val_final_output1_specificity: 0.9649 - val_final_output2_dice_coef: 0.0000e+00 - val_final_output2_iou: 0.0000e+00 - val_final_output2_sensitivity: 0.0000e+00 - val_final_output2_specificity: 0.9994
# Epoch 2/300
# 40/40 [==============================] - ETA: 0s - loss: 3.1622 - final_output1_loss: 1.6001 - final_output2_loss: 1.5621 - final_output1_dice_coef: 0.0430 - final_output1_iou: 0.0224 - final_output1_sensitivity: 0.0195 - final_output1_specificity: 0.9687 - final_output2_dice_coef: 0.1793 - final_output2_iou: 0.1066 - final_output2_sensitivity: 0.1301 - final_output2_specificity: 0.9955
# Epoch 2: val_loss improved from 3.53447 to 3.35339, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 126ms/step - loss: 3.1622 - final_output1_loss: 1.6001 - final_output2_loss: 1.5621 - final_output1_dice_coef: 0.0430 - final_output1_iou: 0.0224 - final_output1_sensitivity: 0.0195 - final_output1_specificity: 0.9687 - final_output2_dice_coef: 0.1793 - final_output2_iou: 0.1066 - final_output2_sensitivity: 0.1301 - final_output2_specificity: 0.9955 - val_loss: 3.3534 - val_final_output1_loss: 1.6731 - val_final_output2_loss: 1.6803 - val_final_output1_dice_coef: 2.8314e-05 - val_final_output1_iou: 1.4159e-05 - val_final_output1_sensitivity: 9.9293e-06 - val_final_output1_specificity: 0.9711 - val_final_output2_dice_coef: 0.0325 - val_final_output2_iou: 0.0168 - val_final_output2_sensitivity: 0.0168 - val_final_output2_specificity: 0.9998
# Epoch 3/300
# 40/40 [==============================] - ETA: 0s - loss: 2.8411 - final_output1_loss: 1.5912 - final_output2_loss: 1.2499 - final_output1_dice_coef: 0.0473 - final_output1_iou: 0.0245 - final_output1_sensitivity: 0.0208 - final_output1_specificity: 0.9735 - final_output2_dice_coef: 0.4523 - final_output2_iou: 0.2987 - final_output2_sensitivity: 0.3914 - final_output2_specificity: 0.9888
# Epoch 3: val_loss did not improve from 3.35339
# 40/40 [==============================] - 5s 124ms/step - loss: 2.8411 - final_output1_loss: 1.5912 - final_output2_loss: 1.2499 - final_output1_dice_coef: 0.0473 - final_output1_iou: 0.0245 - final_output1_sensitivity: 0.0208 - final_output1_specificity: 0.9735 - final_output2_dice_coef: 0.4523 - final_output2_iou: 0.2987 - final_output2_sensitivity: 0.3914 - final_output2_specificity: 0.9888 - val_loss: 3.3695 - val_final_output1_loss: 1.6755 - val_final_output2_loss: 1.6939 - val_final_output1_dice_coef: 2.2716e-05 - val_final_output1_iou: 1.1359e-05 - val_final_output1_sensitivity: 5.6378e-06 - val_final_output1_specificity: 0.9778 - val_final_output2_dice_coef: 0.0803 - val_final_output2_iou: 0.0431 - val_final_output2_sensitivity: 0.0431 - val_final_output2_specificity: 0.9999
# Epoch 4/300
# 40/40 [==============================] - ETA: 0s - loss: 2.7010 - final_output1_loss: 1.5736 - final_output2_loss: 1.1273 - final_output1_dice_coef: 0.0733 - final_output1_iou: 0.0388 - final_output1_sensitivity: 0.0366 - final_output1_specificity: 0.9682 - final_output2_dice_coef: 0.4951 - final_output2_iou: 0.3360 - final_output2_sensitivity: 0.4675 - final_output2_specificity: 0.9870
# Epoch 4: val_loss improved from 3.35339 to 2.95509, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 138ms/step - loss: 2.7010 - final_output1_loss: 1.5736 - final_output2_loss: 1.1273 - final_output1_dice_coef: 0.0733 - final_output1_iou: 0.0388 - final_output1_sensitivity: 0.0366 - final_output1_specificity: 0.9682 - final_output2_dice_coef: 0.4951 - final_output2_iou: 0.3360 - final_output2_sensitivity: 0.4675 - final_output2_specificity: 0.9870 - val_loss: 2.9551 - val_final_output1_loss: 1.6577 - val_final_output2_loss: 1.2973 - val_final_output1_dice_coef: 0.0084 - val_final_output1_iou: 0.0042 - val_final_output1_sensitivity: 0.0025 - val_final_output1_specificity: 0.9755 - val_final_output2_dice_coef: 0.4138 - val_final_output2_iou: 0.2660 - val_final_output2_sensitivity: 0.2899 - val_final_output2_specificity: 0.9971
# Epoch 5/300
# 40/40 [==============================] - ETA: 0s - loss: 2.4184 - final_output1_loss: 1.5224 - final_output2_loss: 0.8961 - final_output1_dice_coef: 0.1359 - final_output1_iou: 0.0735 - final_output1_sensitivity: 0.0746 - final_output1_specificity: 0.9652 - final_output2_dice_coef: 0.6160 - final_output2_iou: 0.4512 - final_output2_sensitivity: 0.5333 - final_output2_specificity: 0.9945
# Epoch 5: val_loss improved from 2.95509 to 2.64202, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 126ms/step - loss: 2.4184 - final_output1_loss: 1.5224 - final_output2_loss: 0.8961 - final_output1_dice_coef: 0.1359 - final_output1_iou: 0.0735 - final_output1_sensitivity: 0.0746 - final_output1_specificity: 0.9652 - final_output2_dice_coef: 0.6160 - final_output2_iou: 0.4512 - final_output2_sensitivity: 0.5333 - final_output2_specificity: 0.9945 - val_loss: 2.6420 - val_final_output1_loss: 1.5594 - val_final_output2_loss: 1.0826 - val_final_output1_dice_coef: 0.1236 - val_final_output1_iou: 0.0661 - val_final_output1_sensitivity: 0.0666 - val_final_output1_specificity: 0.9519 - val_final_output2_dice_coef: 0.5294 - val_final_output2_iou: 0.3638 - val_final_output2_sensitivity: 0.4449 - val_final_output2_specificity: 0.9922
# Epoch 6/300
# 40/40 [==============================] - ETA: 0s - loss: 2.2531 - final_output1_loss: 1.4496 - final_output2_loss: 0.8035 - final_output1_dice_coef: 0.2162 - final_output1_iou: 0.1225 - final_output1_sensitivity: 0.1485 - final_output1_specificity: 0.9546 - final_output2_dice_coef: 0.6621 - final_output2_iou: 0.5010 - final_output2_sensitivity: 0.5994 - final_output2_specificity: 0.9940
# Epoch 6: val_loss improved from 2.64202 to 2.58315, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 128ms/step - loss: 2.2531 - final_output1_loss: 1.4496 - final_output2_loss: 0.8035 - final_output1_dice_coef: 0.2162 - final_output1_iou: 0.1225 - final_output1_sensitivity: 0.1485 - final_output1_specificity: 0.9546 - final_output2_dice_coef: 0.6621 - final_output2_iou: 0.5010 - final_output2_sensitivity: 0.5994 - final_output2_specificity: 0.9940 - val_loss: 2.5831 - val_final_output1_loss: 1.5313 - val_final_output2_loss: 1.0518 - val_final_output1_dice_coef: 0.1279 - val_final_output1_iou: 0.0686 - val_final_output1_sensitivity: 0.0658 - val_final_output1_specificity: 0.9681 - val_final_output2_dice_coef: 0.5347 - val_final_output2_iou: 0.3754 - val_final_output2_sensitivity: 0.4149 - val_final_output2_specificity: 0.9964
# Epoch 7/300
# 40/40 [==============================] - ETA: 0s - loss: 2.1012 - final_output1_loss: 1.3349 - final_output2_loss: 0.7663 - final_output1_dice_coef: 0.3035 - final_output1_iou: 0.1805 - final_output1_sensitivity: 0.2160 - final_output1_specificity: 0.9589 - final_output2_dice_coef: 0.6784 - final_output2_iou: 0.5188 - final_output2_sensitivity: 0.6176 - final_output2_specificity: 0.9942
# Epoch 7: val_loss did not improve from 2.58315
# 40/40 [==============================] - 5s 124ms/step - loss: 2.1012 - final_output1_loss: 1.3349 - final_output2_loss: 0.7663 - final_output1_dice_coef: 0.3035 - final_output1_iou: 0.1805 - final_output1_sensitivity: 0.2160 - final_output1_specificity: 0.9589 - final_output2_dice_coef: 0.6784 - final_output2_iou: 0.5188 - final_output2_sensitivity: 0.6176 - final_output2_specificity: 0.9942 - val_loss: 2.6347 - val_final_output1_loss: 1.3813 - val_final_output2_loss: 1.2534 - val_final_output1_dice_coef: 0.2795 - val_final_output1_iou: 0.1634 - val_final_output1_sensitivity: 0.1681 - val_final_output1_specificity: 0.9697 - val_final_output2_dice_coef: 0.4082 - val_final_output2_iou: 0.2630 - val_final_output2_sensitivity: 0.2674 - val_final_output2_specificity: 0.9994
# Epoch 8/300
# 40/40 [==============================] - ETA: 0s - loss: 1.8904 - final_output1_loss: 1.1463 - final_output2_loss: 0.7441 - final_output1_dice_coef: 0.4420 - final_output1_iou: 0.2856 - final_output1_sensitivity: 0.3790 - final_output1_specificity: 0.9513 - final_output2_dice_coef: 0.6894 - final_output2_iou: 0.5328 - final_output2_sensitivity: 0.6205 - final_output2_specificity: 0.9956
# Epoch 8: val_loss improved from 2.58315 to 2.24881, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 6s 139ms/step - loss: 1.8904 - final_output1_loss: 1.1463 - final_output2_loss: 0.7441 - final_output1_dice_coef: 0.4420 - final_output1_iou: 0.2856 - final_output1_sensitivity: 0.3790 - final_output1_specificity: 0.9513 - final_output2_dice_coef: 0.6894 - final_output2_iou: 0.5328 - final_output2_sensitivity: 0.6205 - final_output2_specificity: 0.9956 - val_loss: 2.2488 - val_final_output1_loss: 1.3400 - val_final_output2_loss: 0.9088 - val_final_output1_dice_coef: 0.2879 - val_final_output1_iou: 0.1688 - val_final_output1_sensitivity: 0.1769 - val_final_output1_specificity: 0.9818 - val_final_output2_dice_coef: 0.6039 - val_final_output2_iou: 0.4451 - val_final_output2_sensitivity: 0.5063 - val_final_output2_specificity: 0.9949
# Epoch 9/300
# 40/40 [==============================] - ETA: 0s - loss: 1.7309 - final_output1_loss: 1.0217 - final_output2_loss: 0.7092 - final_output1_dice_coef: 0.5138 - final_output1_iou: 0.3478 - final_output1_sensitivity: 0.4395 - final_output1_specificity: 0.9616 - final_output2_dice_coef: 0.7048 - final_output2_iou: 0.5543 - final_output2_sensitivity: 0.6367 - final_output2_specificity: 0.9955
# Epoch 9: val_loss improved from 2.24881 to 2.05258, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 127ms/step - loss: 1.7309 - final_output1_loss: 1.0217 - final_output2_loss: 0.7092 - final_output1_dice_coef: 0.5138 - final_output1_iou: 0.3478 - final_output1_sensitivity: 0.4395 - final_output1_specificity: 0.9616 - final_output2_dice_coef: 0.7048 - final_output2_iou: 0.5543 - final_output2_sensitivity: 0.6367 - final_output2_specificity: 0.9955 - val_loss: 2.0526 - val_final_output1_loss: 1.1241 - val_final_output2_loss: 0.9284 - val_final_output1_dice_coef: 0.4582 - val_final_output1_iou: 0.2981 - val_final_output1_sensitivity: 0.3457 - val_final_output1_specificity: 0.9687 - val_final_output2_dice_coef: 0.5965 - val_final_output2_iou: 0.4371 - val_final_output2_sensitivity: 0.4930 - val_final_output2_specificity: 0.9955
# Epoch 10/300
# 40/40 [==============================] - ETA: 0s - loss: 1.6438 - final_output1_loss: 0.9564 - final_output2_loss: 0.6874 - final_output1_dice_coef: 0.5493 - final_output1_iou: 0.3803 - final_output1_sensitivity: 0.4870 - final_output1_specificity: 0.9611 - final_output2_dice_coef: 0.7161 - final_output2_iou: 0.5634 - final_output2_sensitivity: 0.6362 - final_output2_specificity: 0.9958
# Epoch 10: val_loss improved from 2.05258 to 1.82685, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 127ms/step - loss: 1.6438 - final_output1_loss: 0.9564 - final_output2_loss: 0.6874 - final_output1_dice_coef: 0.5493 - final_output1_iou: 0.3803 - final_output1_sensitivity: 0.4870 - final_output1_specificity: 0.9611 - final_output2_dice_coef: 0.7161 - final_output2_iou: 0.5634 - final_output2_sensitivity: 0.6362 - final_output2_specificity: 0.9958 - val_loss: 1.8268 - val_final_output1_loss: 0.9906 - val_final_output2_loss: 0.8362 - val_final_output1_dice_coef: 0.5236 - val_final_output1_iou: 0.3554 - val_final_output1_sensitivity: 0.4051 - val_final_output1_specificity: 0.9720 - val_final_output2_dice_coef: 0.6445 - val_final_output2_iou: 0.4873 - val_final_output2_sensitivity: 0.5958 - val_final_output2_specificity: 0.9926
# Epoch 11/300
# 40/40 [==============================] - ETA: 0s - loss: 1.5585 - final_output1_loss: 0.9120 - final_output2_loss: 0.6465 - final_output1_dice_coef: 0.5719 - final_output1_iou: 0.4019 - final_output1_sensitivity: 0.5062 - final_output1_specificity: 0.9643 - final_output2_dice_coef: 0.7333 - final_output2_iou: 0.5886 - final_output2_sensitivity: 0.6627 - final_output2_specificity: 0.9961
# Epoch 11: val_loss did not improve from 1.82685
# 40/40 [==============================] - 5s 125ms/step - loss: 1.5585 - final_output1_loss: 0.9120 - final_output2_loss: 0.6465 - final_output1_dice_coef: 0.5719 - final_output1_iou: 0.4019 - final_output1_sensitivity: 0.5062 - final_output1_specificity: 0.9643 - final_output2_dice_coef: 0.7333 - final_output2_iou: 0.5886 - final_output2_sensitivity: 0.6627 - final_output2_specificity: 0.9961 - val_loss: 1.9151 - val_final_output1_loss: 0.9789 - val_final_output2_loss: 0.9362 - val_final_output1_dice_coef: 0.5251 - val_final_output1_iou: 0.3569 - val_final_output1_sensitivity: 0.3958 - val_final_output1_specificity: 0.9773 - val_final_output2_dice_coef: 0.5973 - val_final_output2_iou: 0.4306 - val_final_output2_sensitivity: 0.7213 - val_final_output2_specificity: 0.9773
# Epoch 12/300
# 40/40 [==============================] - ETA: 0s - loss: 1.5055 - final_output1_loss: 0.8906 - final_output2_loss: 0.6149 - final_output1_dice_coef: 0.5822 - final_output1_iou: 0.4118 - final_output1_sensitivity: 0.5077 - final_output1_specificity: 0.9666 - final_output2_dice_coef: 0.7492 - final_output2_iou: 0.6051 - final_output2_sensitivity: 0.6809 - final_output2_specificity: 0.9961
# Epoch 12: val_loss did not improve from 1.82685
# 40/40 [==============================] - 5s 125ms/step - loss: 1.5055 - final_output1_loss: 0.8906 - final_output2_loss: 0.6149 - final_output1_dice_coef: 0.5822 - final_output1_iou: 0.4118 - final_output1_sensitivity: 0.5077 - final_output1_specificity: 0.9666 - final_output2_dice_coef: 0.7492 - final_output2_iou: 0.6051 - final_output2_sensitivity: 0.6809 - final_output2_specificity: 0.9961 - val_loss: 1.9292 - val_final_output1_loss: 1.0314 - val_final_output2_loss: 0.8978 - val_final_output1_dice_coef: 0.4956 - val_final_output1_iou: 0.3310 - val_final_output1_sensitivity: 0.3611 - val_final_output1_specificity: 0.9825 - val_final_output2_dice_coef: 0.6106 - val_final_output2_iou: 0.4447 - val_final_output2_sensitivity: 0.7050 - val_final_output2_specificity: 0.9810
# Epoch 13/300
# 40/40 [==============================] - ETA: 0s - loss: 1.4683 - final_output1_loss: 0.8608 - final_output2_loss: 0.6074 - final_output1_dice_coef: 0.5970 - final_output1_iou: 0.4266 - final_output1_sensitivity: 0.5285 - final_output1_specificity: 0.9666 - final_output2_dice_coef: 0.7522 - final_output2_iou: 0.6082 - final_output2_sensitivity: 0.7029 - final_output2_specificity: 0.9950
# Epoch 13: val_loss improved from 1.82685 to 1.61697, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 136ms/step - loss: 1.4683 - final_output1_loss: 0.8608 - final_output2_loss: 0.6074 - final_output1_dice_coef: 0.5970 - final_output1_iou: 0.4266 - final_output1_sensitivity: 0.5285 - final_output1_specificity: 0.9666 - final_output2_dice_coef: 0.7522 - final_output2_iou: 0.6082 - final_output2_sensitivity: 0.7029 - final_output2_specificity: 0.9950 - val_loss: 1.6170 - val_final_output1_loss: 0.9149 - val_final_output2_loss: 0.7020 - val_final_output1_dice_coef: 0.5606 - val_final_output1_iou: 0.3909 - val_final_output1_sensitivity: 0.4347 - val_final_output1_specificity: 0.9790 - val_final_output2_dice_coef: 0.7044 - val_final_output2_iou: 0.5571 - val_final_output2_sensitivity: 0.6417 - val_final_output2_specificity: 0.9948
# Epoch 14/300
# 40/40 [==============================] - ETA: 0s - loss: 1.4368 - final_output1_loss: 0.8463 - final_output2_loss: 0.5905 - final_output1_dice_coef: 0.6037 - final_output1_iou: 0.4336 - final_output1_sensitivity: 0.5366 - final_output1_specificity: 0.9666 - final_output2_dice_coef: 0.7574 - final_output2_iou: 0.6184 - final_output2_sensitivity: 0.7050 - final_output2_specificity: 0.9954
# Epoch 14: val_loss did not improve from 1.61697
# 40/40 [==============================] - 5s 125ms/step - loss: 1.4368 - final_output1_loss: 0.8463 - final_output2_loss: 0.5905 - final_output1_dice_coef: 0.6037 - final_output1_iou: 0.4336 - final_output1_sensitivity: 0.5366 - final_output1_specificity: 0.9666 - final_output2_dice_coef: 0.7574 - final_output2_iou: 0.6184 - final_output2_sensitivity: 0.7050 - final_output2_specificity: 0.9954 - val_loss: 1.6592 - val_final_output1_loss: 0.9124 - val_final_output2_loss: 0.7468 - val_final_output1_dice_coef: 0.5587 - val_final_output1_iou: 0.3886 - val_final_output1_sensitivity: 0.4136 - val_final_output1_specificity: 0.9850 - val_final_output2_dice_coef: 0.6815 - val_final_output2_iou: 0.5338 - val_final_output2_sensitivity: 0.5737 - val_final_output2_specificity: 0.9975
# Epoch 15/300
# 40/40 [==============================] - ETA: 0s - loss: 1.4387 - final_output1_loss: 0.8450 - final_output2_loss: 0.5937 - final_output1_dice_coef: 0.6053 - final_output1_iou: 0.4353 - final_output1_sensitivity: 0.5319 - final_output1_specificity: 0.9687 - final_output2_dice_coef: 0.7589 - final_output2_iou: 0.6169 - final_output2_sensitivity: 0.6914 - final_output2_specificity: 0.9960
# Epoch 15: val_loss did not improve from 1.61697
# 40/40 [==============================] - 5s 125ms/step - loss: 1.4387 - final_output1_loss: 0.8450 - final_output2_loss: 0.5937 - final_output1_dice_coef: 0.6053 - final_output1_iou: 0.4353 - final_output1_sensitivity: 0.5319 - final_output1_specificity: 0.9687 - final_output2_dice_coef: 0.7589 - final_output2_iou: 0.6169 - final_output2_sensitivity: 0.6914 - final_output2_specificity: 0.9960 - val_loss: 1.6421 - val_final_output1_loss: 0.9701 - val_final_output2_loss: 0.6719 - val_final_output1_dice_coef: 0.5295 - val_final_output1_iou: 0.3612 - val_final_output1_sensitivity: 0.3763 - val_final_output1_specificity: 0.9887 - val_final_output2_dice_coef: 0.7207 - val_final_output2_iou: 0.5736 - val_final_output2_sensitivity: 0.7195 - val_final_output2_specificity: 0.9911
# Epoch 16/300
# 40/40 [==============================] - ETA: 0s - loss: 1.3901 - final_output1_loss: 0.8340 - final_output2_loss: 0.5560 - final_output1_dice_coef: 0.6104 - final_output1_iou: 0.4407 - final_output1_sensitivity: 0.5403 - final_output1_specificity: 0.9686 - final_output2_dice_coef: 0.7744 - final_output2_iou: 0.6388 - final_output2_sensitivity: 0.7195 - final_output2_specificity: 0.9960
# Epoch 16: val_loss did not improve from 1.61697
# 40/40 [==============================] - 5s 125ms/step - loss: 1.3901 - final_output1_loss: 0.8340 - final_output2_loss: 0.5560 - final_output1_dice_coef: 0.6104 - final_output1_iou: 0.4407 - final_output1_sensitivity: 0.5403 - final_output1_specificity: 0.9686 - final_output2_dice_coef: 0.7744 - final_output2_iou: 0.6388 - final_output2_sensitivity: 0.7195 - final_output2_specificity: 0.9960 - val_loss: 1.7757 - val_final_output1_loss: 1.0575 - val_final_output2_loss: 0.7183 - val_final_output1_dice_coef: 0.4856 - val_final_output1_iou: 0.3223 - val_final_output1_sensitivity: 0.3370 - val_final_output1_specificity: 0.9899 - val_final_output2_dice_coef: 0.7023 - val_final_output2_iou: 0.5503 - val_final_output2_sensitivity: 0.6881 - val_final_output2_specificity: 0.9902
# Epoch 17/300
# 40/40 [==============================] - ETA: 0s - loss: 1.3908 - final_output1_loss: 0.8343 - final_output2_loss: 0.5565 - final_output1_dice_coef: 0.6096 - final_output1_iou: 0.4403 - final_output1_sensitivity: 0.5445 - final_output1_specificity: 0.9678 - final_output2_dice_coef: 0.7748 - final_output2_iou: 0.6380 - final_output2_sensitivity: 0.7248 - final_output2_specificity: 0.9954
# Epoch 17: val_loss improved from 1.61697 to 1.56079, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 137ms/step - loss: 1.3908 - final_output1_loss: 0.8343 - final_output2_loss: 0.5565 - final_output1_dice_coef: 0.6096 - final_output1_iou: 0.4403 - final_output1_sensitivity: 0.5445 - final_output1_specificity: 0.9678 - final_output2_dice_coef: 0.7748 - final_output2_iou: 0.6380 - final_output2_sensitivity: 0.7248 - final_output2_specificity: 0.9954 - val_loss: 1.5608 - val_final_output1_loss: 0.8751 - val_final_output2_loss: 0.6857 - val_final_output1_dice_coef: 0.5820 - val_final_output1_iou: 0.4120 - val_final_output1_sensitivity: 0.4427 - val_final_output1_specificity: 0.9853 - val_final_output2_dice_coef: 0.7074 - val_final_output2_iou: 0.5682 - val_final_output2_sensitivity: 0.6144 - val_final_output2_specificity: 0.9973
# Epoch 18/300
# 40/40 [==============================] - ETA: 0s - loss: 1.3280 - final_output1_loss: 0.8017 - final_output2_loss: 0.5263 - final_output1_dice_coef: 0.6263 - final_output1_iou: 0.4573 - final_output1_sensitivity: 0.5565 - final_output1_specificity: 0.9693 - final_output2_dice_coef: 0.7863 - final_output2_iou: 0.6536 - final_output2_sensitivity: 0.7409 - final_output2_specificity: 0.9955
# Epoch 18: val_loss improved from 1.56079 to 1.46738, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 126ms/step - loss: 1.3280 - final_output1_loss: 0.8017 - final_output2_loss: 0.5263 - final_output1_dice_coef: 0.6263 - final_output1_iou: 0.4573 - final_output1_sensitivity: 0.5565 - final_output1_specificity: 0.9693 - final_output2_dice_coef: 0.7863 - final_output2_iou: 0.6536 - final_output2_sensitivity: 0.7409 - final_output2_specificity: 0.9955 - val_loss: 1.4674 - val_final_output1_loss: 0.8265 - val_final_output2_loss: 0.6409 - val_final_output1_dice_coef: 0.6083 - val_final_output1_iou: 0.4381 - val_final_output1_sensitivity: 0.4815 - val_final_output1_specificity: 0.9826 - val_final_output2_dice_coef: 0.7326 - val_final_output2_iou: 0.5924 - val_final_output2_sensitivity: 0.6819 - val_final_output2_specificity: 0.9945
# Epoch 19/300
# 40/40 [==============================] - ETA: 0s - loss: 1.3370 - final_output1_loss: 0.8045 - final_output2_loss: 0.5325 - final_output1_dice_coef: 0.6246 - final_output1_iou: 0.4553 - final_output1_sensitivity: 0.5482 - final_output1_specificity: 0.9710 - final_output2_dice_coef: 0.7837 - final_output2_iou: 0.6514 - final_output2_sensitivity: 0.7404 - final_output2_specificity: 0.9953
# Epoch 19: val_loss improved from 1.46738 to 1.42892, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 128ms/step - loss: 1.3370 - final_output1_loss: 0.8045 - final_output2_loss: 0.5325 - final_output1_dice_coef: 0.6246 - final_output1_iou: 0.4553 - final_output1_sensitivity: 0.5482 - final_output1_specificity: 0.9710 - final_output2_dice_coef: 0.7837 - final_output2_iou: 0.6514 - final_output2_sensitivity: 0.7404 - final_output2_specificity: 0.9953 - val_loss: 1.4289 - val_final_output1_loss: 0.7711 - val_final_output2_loss: 0.6579 - val_final_output1_dice_coef: 0.6422 - val_final_output1_iou: 0.4735 - val_final_output1_sensitivity: 0.5626 - val_final_output1_specificity: 0.9708 - val_final_output2_dice_coef: 0.7268 - val_final_output2_iou: 0.5808 - val_final_output2_sensitivity: 0.7807 - val_final_output2_specificity: 0.9873
# Epoch 20/300
# 40/40 [==============================] - ETA: 0s - loss: 1.3296 - final_output1_loss: 0.8018 - final_output2_loss: 0.5279 - final_output1_dice_coef: 0.6277 - final_output1_iou: 0.4582 - final_output1_sensitivity: 0.5575 - final_output1_specificity: 0.9696 - final_output2_dice_coef: 0.7857 - final_output2_iou: 0.6557 - final_output2_sensitivity: 0.7427 - final_output2_specificity: 0.9956
# Epoch 20: val_loss improved from 1.42892 to 1.39271, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 126ms/step - loss: 1.3296 - final_output1_loss: 0.8018 - final_output2_loss: 0.5279 - final_output1_dice_coef: 0.6277 - final_output1_iou: 0.4582 - final_output1_sensitivity: 0.5575 - final_output1_specificity: 0.9696 - final_output2_dice_coef: 0.7857 - final_output2_iou: 0.6557 - final_output2_sensitivity: 0.7427 - final_output2_specificity: 0.9956 - val_loss: 1.3927 - val_final_output1_loss: 0.8070 - val_final_output2_loss: 0.5857 - val_final_output1_dice_coef: 0.6171 - val_final_output1_iou: 0.4471 - val_final_output1_sensitivity: 0.4935 - val_final_output1_specificity: 0.9817 - val_final_output2_dice_coef: 0.7586 - val_final_output2_iou: 0.6227 - val_final_output2_sensitivity: 0.7019 - val_final_output2_specificity: 0.9956
# Epoch 21/300
# 40/40 [==============================] - ETA: 0s - loss: 1.2891 - final_output1_loss: 0.7930 - final_output2_loss: 0.4961 - final_output1_dice_coef: 0.6306 - final_output1_iou: 0.4617 - final_output1_sensitivity: 0.5607 - final_output1_specificity: 0.9698 - final_output2_dice_coef: 0.8003 - final_output2_iou: 0.6720 - final_output2_sensitivity: 0.7576 - final_output2_specificity: 0.9959
# Epoch 21: val_loss did not improve from 1.39271
# 40/40 [==============================] - 5s 124ms/step - loss: 1.2891 - final_output1_loss: 0.7930 - final_output2_loss: 0.4961 - final_output1_dice_coef: 0.6306 - final_output1_iou: 0.4617 - final_output1_sensitivity: 0.5607 - final_output1_specificity: 0.9698 - final_output2_dice_coef: 0.8003 - final_output2_iou: 0.6720 - final_output2_sensitivity: 0.7576 - final_output2_specificity: 0.9959 - val_loss: 1.5342 - val_final_output1_loss: 0.7910 - val_final_output2_loss: 0.7432 - val_final_output1_dice_coef: 0.6282 - val_final_output1_iou: 0.4586 - val_final_output1_sensitivity: 0.5205 - val_final_output1_specificity: 0.9783 - val_final_output2_dice_coef: 0.6869 - val_final_output2_iou: 0.5378 - val_final_output2_sensitivity: 0.5549 - val_final_output2_specificity: 0.9988
# Epoch 22/300
# 40/40 [==============================] - ETA: 0s - loss: 1.2624 - final_output1_loss: 0.7836 - final_output2_loss: 0.4788 - final_output1_dice_coef: 0.6346 - final_output1_iou: 0.4662 - final_output1_sensitivity: 0.5625 - final_output1_specificity: 0.9704 - final_output2_dice_coef: 0.8079 - final_output2_iou: 0.6842 - final_output2_sensitivity: 0.7651 - final_output2_specificity: 0.9961
# Epoch 22: val_loss did not improve from 1.39271
# 40/40 [==============================] - 5s 125ms/step - loss: 1.2624 - final_output1_loss: 0.7836 - final_output2_loss: 0.4788 - final_output1_dice_coef: 0.6346 - final_output1_iou: 0.4662 - final_output1_sensitivity: 0.5625 - final_output1_specificity: 0.9704 - final_output2_dice_coef: 0.8079 - final_output2_iou: 0.6842 - final_output2_sensitivity: 0.7651 - final_output2_specificity: 0.9961 - val_loss: 1.4800 - val_final_output1_loss: 0.7554 - val_final_output2_loss: 0.7246 - val_final_output1_dice_coef: 0.6477 - val_final_output1_iou: 0.4798 - val_final_output1_sensitivity: 0.5613 - val_final_output1_specificity: 0.9734 - val_final_output2_dice_coef: 0.7018 - val_final_output2_iou: 0.5470 - val_final_output2_sensitivity: 0.7822 - val_final_output2_specificity: 0.9846
# Epoch 23/300
# 40/40 [==============================] - ETA: 0s - loss: 1.2836 - final_output1_loss: 0.7794 - final_output2_loss: 0.5042 - final_output1_dice_coef: 0.6366 - final_output1_iou: 0.4679 - final_output1_sensitivity: 0.5681 - final_output1_specificity: 0.9701 - final_output2_dice_coef: 0.7964 - final_output2_iou: 0.6688 - final_output2_sensitivity: 0.7603 - final_output2_specificity: 0.9953
# Epoch 23: val_loss did not improve from 1.39271
# 40/40 [==============================] - 5s 124ms/step - loss: 1.2836 - final_output1_loss: 0.7794 - final_output2_loss: 0.5042 - final_output1_dice_coef: 0.6366 - final_output1_iou: 0.4679 - final_output1_sensitivity: 0.5681 - final_output1_specificity: 0.9701 - final_output2_dice_coef: 0.7964 - final_output2_iou: 0.6688 - final_output2_sensitivity: 0.7603 - final_output2_specificity: 0.9953 - val_loss: 1.4298 - val_final_output1_loss: 0.8033 - val_final_output2_loss: 0.6266 - val_final_output1_dice_coef: 0.6187 - val_final_output1_iou: 0.4487 - val_final_output1_sensitivity: 0.4860 - val_final_output1_specificity: 0.9836 - val_final_output2_dice_coef: 0.7423 - val_final_output2_iou: 0.5999 - val_final_output2_sensitivity: 0.7695 - val_final_output2_specificity: 0.9896
# Epoch 24/300
# 40/40 [==============================] - ETA: 0s - loss: 1.2194 - final_output1_loss: 0.7687 - final_output2_loss: 0.4507 - final_output1_dice_coef: 0.6426 - final_output1_iou: 0.4744 - final_output1_sensitivity: 0.5763 - final_output1_specificity: 0.9700 - final_output2_dice_coef: 0.8207 - final_output2_iou: 0.6993 - final_output2_sensitivity: 0.7798 - final_output2_specificity: 0.9962
# Epoch 24: val_loss improved from 1.39271 to 1.37989, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 135ms/step - loss: 1.2194 - final_output1_loss: 0.7687 - final_output2_loss: 0.4507 - final_output1_dice_coef: 0.6426 - final_output1_iou: 0.4744 - final_output1_sensitivity: 0.5763 - final_output1_specificity: 0.9700 - final_output2_dice_coef: 0.8207 - final_output2_iou: 0.6993 - final_output2_sensitivity: 0.7798 - final_output2_specificity: 0.9962 - val_loss: 1.3799 - val_final_output1_loss: 0.7722 - val_final_output2_loss: 0.6077 - val_final_output1_dice_coef: 0.6347 - val_final_output1_iou: 0.4656 - val_final_output1_sensitivity: 0.5066 - val_final_output1_specificity: 0.9832 - val_final_output2_dice_coef: 0.7524 - val_final_output2_iou: 0.6123 - val_final_output2_sensitivity: 0.7840 - val_final_output2_specificity: 0.9891
# Epoch 25/300
# 40/40 [==============================] - ETA: 0s - loss: 1.2099 - final_output1_loss: 0.7629 - final_output2_loss: 0.4471 - final_output1_dice_coef: 0.6446 - final_output1_iou: 0.4769 - final_output1_sensitivity: 0.5699 - final_output1_specificity: 0.9718 - final_output2_dice_coef: 0.8212 - final_output2_iou: 0.7011 - final_output2_sensitivity: 0.7875 - final_output2_specificity: 0.9959
# Epoch 25: val_loss improved from 1.37989 to 1.33373, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 127ms/step - loss: 1.2099 - final_output1_loss: 0.7629 - final_output2_loss: 0.4471 - final_output1_dice_coef: 0.6446 - final_output1_iou: 0.4769 - final_output1_sensitivity: 0.5699 - final_output1_specificity: 0.9718 - final_output2_dice_coef: 0.8212 - final_output2_iou: 0.7011 - final_output2_sensitivity: 0.7875 - final_output2_specificity: 0.9959 - val_loss: 1.3337 - val_final_output1_loss: 0.7321 - val_final_output2_loss: 0.6016 - val_final_output1_dice_coef: 0.6585 - val_final_output1_iou: 0.4914 - val_final_output1_sensitivity: 0.5790 - val_final_output1_specificity: 0.9742 - val_final_output2_dice_coef: 0.7510 - val_final_output2_iou: 0.6173 - val_final_output2_sensitivity: 0.6732 - val_final_output2_specificity: 0.9966
# Epoch 26/300
# 40/40 [==============================] - ETA: 0s - loss: 1.2349 - final_output1_loss: 0.7549 - final_output2_loss: 0.4799 - final_output1_dice_coef: 0.6492 - final_output1_iou: 0.4815 - final_output1_sensitivity: 0.5797 - final_output1_specificity: 0.9712 - final_output2_dice_coef: 0.8067 - final_output2_iou: 0.6841 - final_output2_sensitivity: 0.7579 - final_output2_specificity: 0.9965
# Epoch 26: val_loss did not improve from 1.33373
# 40/40 [==============================] - 5s 125ms/step - loss: 1.2349 - final_output1_loss: 0.7549 - final_output2_loss: 0.4799 - final_output1_dice_coef: 0.6492 - final_output1_iou: 0.4815 - final_output1_sensitivity: 0.5797 - final_output1_specificity: 0.9712 - final_output2_dice_coef: 0.8067 - final_output2_iou: 0.6841 - final_output2_sensitivity: 0.7579 - final_output2_specificity: 0.9965 - val_loss: 1.4409 - val_final_output1_loss: 0.8134 - val_final_output2_loss: 0.6276 - val_final_output1_dice_coef: 0.6127 - val_final_output1_iou: 0.4425 - val_final_output1_sensitivity: 0.4774 - val_final_output1_specificity: 0.9846 - val_final_output2_dice_coef: 0.7438 - val_final_output2_iou: 0.6022 - val_final_output2_sensitivity: 0.7464 - val_final_output2_specificity: 0.9911
# Epoch 27/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1767 - final_output1_loss: 0.7546 - final_output2_loss: 0.4221 - final_output1_dice_coef: 0.6485 - final_output1_iou: 0.4810 - final_output1_sensitivity: 0.5717 - final_output1_specificity: 0.9731 - final_output2_dice_coef: 0.8326 - final_output2_iou: 0.7174 - final_output2_sensitivity: 0.7976 - final_output2_specificity: 0.9962
# Epoch 27: val_loss improved from 1.33373 to 1.27064, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 6s 152ms/step - loss: 1.1767 - final_output1_loss: 0.7546 - final_output2_loss: 0.4221 - final_output1_dice_coef: 0.6485 - final_output1_iou: 0.4810 - final_output1_sensitivity: 0.5717 - final_output1_specificity: 0.9731 - final_output2_dice_coef: 0.8326 - final_output2_iou: 0.7174 - final_output2_sensitivity: 0.7976 - final_output2_specificity: 0.9962 - val_loss: 1.2706 - val_final_output1_loss: 0.7166 - val_final_output2_loss: 0.5540 - val_final_output1_dice_coef: 0.6715 - val_final_output1_iou: 0.5060 - val_final_output1_sensitivity: 0.6338 - val_final_output1_specificity: 0.9651 - val_final_output2_dice_coef: 0.7738 - val_final_output2_iou: 0.6414 - val_final_output2_sensitivity: 0.8034 - val_final_output2_specificity: 0.9905
# Epoch 28/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1891 - final_output1_loss: 0.7516 - final_output2_loss: 0.4375 - final_output1_dice_coef: 0.6510 - final_output1_iou: 0.4837 - final_output1_sensitivity: 0.5825 - final_output1_specificity: 0.9714 - final_output2_dice_coef: 0.8241 - final_output2_iou: 0.7079 - final_output2_sensitivity: 0.7972 - final_output2_specificity: 0.9955
# Epoch 28: val_loss did not improve from 1.27064
# 40/40 [==============================] - 5s 125ms/step - loss: 1.1891 - final_output1_loss: 0.7516 - final_output2_loss: 0.4375 - final_output1_dice_coef: 0.6510 - final_output1_iou: 0.4837 - final_output1_sensitivity: 0.5825 - final_output1_specificity: 0.9714 - final_output2_dice_coef: 0.8241 - final_output2_iou: 0.7079 - final_output2_sensitivity: 0.7972 - final_output2_specificity: 0.9955 - val_loss: 1.6243 - val_final_output1_loss: 0.7721 - val_final_output2_loss: 0.8522 - val_final_output1_dice_coef: 0.6352 - val_final_output1_iou: 0.4660 - val_final_output1_sensitivity: 0.5103 - val_final_output1_specificity: 0.9824 - val_final_output2_dice_coef: 0.6336 - val_final_output2_iou: 0.4730 - val_final_output2_sensitivity: 0.8095 - val_final_output2_specificity: 0.9741
# Epoch 29/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1929 - final_output1_loss: 0.7533 - final_output2_loss: 0.4397 - final_output1_dice_coef: 0.6495 - final_output1_iou: 0.4822 - final_output1_sensitivity: 0.5774 - final_output1_specificity: 0.9715 - final_output2_dice_coef: 0.8240 - final_output2_iou: 0.7082 - final_output2_sensitivity: 0.7868 - final_output2_specificity: 0.9962
# Epoch 29: val_loss did not improve from 1.27064
# 40/40 [==============================] - 5s 125ms/step - loss: 1.1929 - final_output1_loss: 0.7533 - final_output2_loss: 0.4397 - final_output1_dice_coef: 0.6495 - final_output1_iou: 0.4822 - final_output1_sensitivity: 0.5774 - final_output1_specificity: 0.9715 - final_output2_dice_coef: 0.8240 - final_output2_iou: 0.7082 - final_output2_sensitivity: 0.7868 - final_output2_specificity: 0.9962 - val_loss: 1.2818 - val_final_output1_loss: 0.7538 - val_final_output2_loss: 0.5280 - val_final_output1_dice_coef: 0.6449 - val_final_output1_iou: 0.4769 - val_final_output1_sensitivity: 0.5239 - val_final_output1_specificity: 0.9827 - val_final_output2_dice_coef: 0.7813 - val_final_output2_iou: 0.6550 - val_final_output2_sensitivity: 0.7085 - val_final_output2_specificity: 0.9970
# Epoch 30/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1948 - final_output1_loss: 0.7508 - final_output2_loss: 0.4440 - final_output1_dice_coef: 0.6508 - final_output1_iou: 0.4837 - final_output1_sensitivity: 0.5786 - final_output1_specificity: 0.9723 - final_output2_dice_coef: 0.8232 - final_output2_iou: 0.7045 - final_output2_sensitivity: 0.7884 - final_output2_specificity: 0.9961
# Epoch 30: val_loss improved from 1.27064 to 1.22635, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 6s 138ms/step - loss: 1.1948 - final_output1_loss: 0.7508 - final_output2_loss: 0.4440 - final_output1_dice_coef: 0.6508 - final_output1_iou: 0.4837 - final_output1_sensitivity: 0.5786 - final_output1_specificity: 0.9723 - final_output2_dice_coef: 0.8232 - final_output2_iou: 0.7045 - final_output2_sensitivity: 0.7884 - final_output2_specificity: 0.9961 - val_loss: 1.2264 - val_final_output1_loss: 0.7080 - val_final_output2_loss: 0.5183 - val_final_output1_dice_coef: 0.6751 - val_final_output1_iou: 0.5100 - val_final_output1_sensitivity: 0.6499 - val_final_output1_specificity: 0.9635 - val_final_output2_dice_coef: 0.7879 - val_final_output2_iou: 0.6626 - val_final_output2_sensitivity: 0.7182 - val_final_output2_specificity: 0.9968
# Epoch 31/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1549 - final_output1_loss: 0.7367 - final_output2_loss: 0.4182 - final_output1_dice_coef: 0.6579 - final_output1_iou: 0.4916 - final_output1_sensitivity: 0.5861 - final_output1_specificity: 0.9722 - final_output2_dice_coef: 0.8329 - final_output2_iou: 0.7209 - final_output2_sensitivity: 0.7984 - final_output2_specificity: 0.9963
# Epoch 31: val_loss improved from 1.22635 to 1.20875, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 127ms/step - loss: 1.1549 - final_output1_loss: 0.7367 - final_output2_loss: 0.4182 - final_output1_dice_coef: 0.6579 - final_output1_iou: 0.4916 - final_output1_sensitivity: 0.5861 - final_output1_specificity: 0.9722 - final_output2_dice_coef: 0.8329 - final_output2_iou: 0.7209 - final_output2_sensitivity: 0.7984 - final_output2_specificity: 0.9963 - val_loss: 1.2088 - val_final_output1_loss: 0.7038 - val_final_output2_loss: 0.5050 - val_final_output1_dice_coef: 0.6746 - val_final_output1_iou: 0.5094 - val_final_output1_sensitivity: 0.6190 - val_final_output1_specificity: 0.9696 - val_final_output2_dice_coef: 0.7955 - val_final_output2_iou: 0.6739 - val_final_output2_sensitivity: 0.7368 - val_final_output2_specificity: 0.9963
# Epoch 32/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1119 - final_output1_loss: 0.7286 - final_output2_loss: 0.3833 - final_output1_dice_coef: 0.6618 - final_output1_iou: 0.4957 - final_output1_sensitivity: 0.5912 - final_output1_specificity: 0.9721 - final_output2_dice_coef: 0.8496 - final_output2_iou: 0.7424 - final_output2_sensitivity: 0.8185 - final_output2_specificity: 0.9964
# Epoch 32: val_loss improved from 1.20875 to 1.15824, saving model to /content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5
# 40/40 [==============================] - 5s 126ms/step - loss: 1.1119 - final_output1_loss: 0.7286 - final_output2_loss: 0.3833 - final_output1_dice_coef: 0.6618 - final_output1_iou: 0.4957 - final_output1_sensitivity: 0.5912 - final_output1_specificity: 0.9721 - final_output2_dice_coef: 0.8496 - final_output2_iou: 0.7424 - final_output2_sensitivity: 0.8185 - final_output2_specificity: 0.9964 - val_loss: 1.1582 - val_final_output1_loss: 0.6931 - val_final_output2_loss: 0.4652 - val_final_output1_dice_coef: 0.6781 - val_final_output1_iou: 0.5135 - val_final_output1_sensitivity: 0.6125 - val_final_output1_specificity: 0.9730 - val_final_output2_dice_coef: 0.8115 - val_final_output2_iou: 0.6939 - val_final_output2_sensitivity: 0.7632 - val_final_output2_specificity: 0.9964
# Epoch 33/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1653 - final_output1_loss: 0.7348 - final_output2_loss: 0.4305 - final_output1_dice_coef: 0.6589 - final_output1_iou: 0.4923 - final_output1_sensitivity: 0.5848 - final_output1_specificity: 0.9729 - final_output2_dice_coef: 0.8272 - final_output2_iou: 0.7115 - final_output2_sensitivity: 0.7924 - final_output2_specificity: 0.9962
# Epoch 33: val_loss did not improve from 1.15824
# 40/40 [==============================] - 5s 125ms/step - loss: 1.1653 - final_output1_loss: 0.7348 - final_output2_loss: 0.4305 - final_output1_dice_coef: 0.6589 - final_output1_iou: 0.4923 - final_output1_sensitivity: 0.5848 - final_output1_specificity: 0.9729 - final_output2_dice_coef: 0.8272 - final_output2_iou: 0.7115 - final_output2_sensitivity: 0.7924 - final_output2_specificity: 0.9962 - val_loss: 1.2077 - val_final_output1_loss: 0.7095 - val_final_output2_loss: 0.4983 - val_final_output1_dice_coef: 0.6700 - val_final_output1_iou: 0.5041 - val_final_output1_sensitivity: 0.5801 - val_final_output1_specificity: 0.9758 - val_final_output2_dice_coef: 0.7976 - val_final_output2_iou: 0.6749 - val_final_output2_sensitivity: 0.7807 - val_final_output2_specificity: 0.9937
# Epoch 34/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1553 - final_output1_loss: 0.7405 - final_output2_loss: 0.4149 - final_output1_dice_coef: 0.6562 - final_output1_iou: 0.4893 - final_output1_sensitivity: 0.5831 - final_output1_specificity: 0.9726 - final_output2_dice_coef: 0.8337 - final_output2_iou: 0.7205 - final_output2_sensitivity: 0.8060 - final_output2_specificity: 0.9960
# Epoch 34: val_loss did not improve from 1.15824
# 40/40 [==============================] - 5s 126ms/step - loss: 1.1553 - final_output1_loss: 0.7405 - final_output2_loss: 0.4149 - final_output1_dice_coef: 0.6562 - final_output1_iou: 0.4893 - final_output1_sensitivity: 0.5831 - final_output1_specificity: 0.9726 - final_output2_dice_coef: 0.8337 - final_output2_iou: 0.7205 - final_output2_sensitivity: 0.8060 - final_output2_specificity: 0.9960 - val_loss: 1.2829 - val_final_output1_loss: 0.7200 - val_final_output2_loss: 0.5629 - val_final_output1_dice_coef: 0.6636 - val_final_output1_iou: 0.4972 - val_final_output1_sensitivity: 0.5615 - val_final_output1_specificity: 0.9787 - val_final_output2_dice_coef: 0.7700 - val_final_output2_iou: 0.6344 - val_final_output2_sensitivity: 0.7619 - val_final_output2_specificity: 0.9932
# Epoch 35/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1580 - final_output1_loss: 0.7277 - final_output2_loss: 0.4303 - final_output1_dice_coef: 0.6622 - final_output1_iou: 0.4959 - final_output1_sensitivity: 0.5893 - final_output1_specificity: 0.9729 - final_output2_dice_coef: 0.8277 - final_output2_iou: 0.7110 - final_output2_sensitivity: 0.7927 - final_output2_specificity: 0.9963
# Epoch 35: val_loss did not improve from 1.15824
# 40/40 [==============================] - 5s 125ms/step - loss: 1.1580 - final_output1_loss: 0.7277 - final_output2_loss: 0.4303 - final_output1_dice_coef: 0.6622 - final_output1_iou: 0.4959 - final_output1_sensitivity: 0.5893 - final_output1_specificity: 0.9729 - final_output2_dice_coef: 0.8277 - final_output2_iou: 0.7110 - final_output2_sensitivity: 0.7927 - final_output2_specificity: 0.9963 - val_loss: 1.2276 - val_final_output1_loss: 0.6904 - val_final_output2_loss: 0.5372 - val_final_output1_dice_coef: 0.6786 - val_final_output1_iou: 0.5141 - val_final_output1_sensitivity: 0.6011 - val_final_output1_specificity: 0.9750 - val_final_output2_dice_coef: 0.7790 - val_final_output2_iou: 0.6524 - val_final_output2_sensitivity: 0.7105 - val_final_output2_specificity: 0.9963
# Epoch 36/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1159 - final_output1_loss: 0.7151 - final_output2_loss: 0.4008 - final_output1_dice_coef: 0.6685 - final_output1_iou: 0.5028 - final_output1_sensitivity: 0.5947 - final_output1_specificity: 0.9731 - final_output2_dice_coef: 0.8397 - final_output2_iou: 0.7297 - final_output2_sensitivity: 0.8125 - final_output2_specificity: 0.9964
# Epoch 36: val_loss did not improve from 1.15824
# 40/40 [==============================] - 5s 125ms/step - loss: 1.1159 - final_output1_loss: 0.7151 - final_output2_loss: 0.4008 - final_output1_dice_coef: 0.6685 - final_output1_iou: 0.5028 - final_output1_sensitivity: 0.5947 - final_output1_specificity: 0.9731 - final_output2_dice_coef: 0.8397 - final_output2_iou: 0.7297 - final_output2_sensitivity: 0.8125 - final_output2_specificity: 0.9964 - val_loss: 1.2567 - val_final_output1_loss: 0.6910 - val_final_output2_loss: 0.5657 - val_final_output1_dice_coef: 0.6791 - val_final_output1_iou: 0.5146 - val_final_output1_sensitivity: 0.5955 - val_final_output1_specificity: 0.9751 - val_final_output2_dice_coef: 0.7675 - val_final_output2_iou: 0.6365 - val_final_output2_sensitivity: 0.6649 - val_final_output2_specificity: 0.9983
# Epoch 37/300
# 40/40 [==============================] - ETA: 0s - loss: 1.1343 - final_output1_loss: 0.7223 - final_output2_loss: 0.4120 - final_output1_dice_coef: 0.6646 - final_output1_iou: 0.4991 - final_output1_sensitivity: 0.5934 - final_output1_specificity: 0.9728 - final_output2_dice_coef: 0.8347 - final_output2_iou: 0.7249 - final_output2_sensitivity: 0.8076 - final_output2_specificity: 0.9960
# Epoch 37: val_loss did not improve from 1.15824
# 40/40 [==============================] - 5s 125ms/step - loss: 1.1343 - final_output1_loss: 0.7223 - final_output2_loss: 0.4120 - final_output1_dice_coef: 0.6646 - final_output1_iou: 0.4991 - final_output1_sensitivity: 0.5934 - final_output1_specificity: 0.9728 - final_output2_dice_coef: 0.8347 - final_output2_iou: 0.7249 - final_output2_sensitivity: 0.8076 - final_output2_specificity: 0.9960 - val_loss: 1.4224 - val_final_output1_loss: 0.7314 - val_final_output2_loss: 0.6910 - val_final_output1_dice_coef: 0.6547 - val_final_output1_iou: 0.4874 - val_final_output1_sensitivity: 0.5314 - val_final_output1_specificity: 0.9831 - val_final_output2_dice_coef: 0.7084 - val_final_output2_iou: 0.5671 - val_final_output2_sensitivity: 0.7153 - val_final_output2_specificity: 0.9915
# Epoch 38/300
# ...
# Epoch 288: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.6966 - final_output1_loss: 0.5599 - final_output2_loss: 0.1366 - final_output1_dice_coef: 0.7398 - final_output1_iou: 0.5877 - final_output1_sensitivity: 0.6727 - final_output1_specificity: 0.9767 - final_output2_dice_coef: 0.9477 - final_output2_iou: 0.9028 - final_output2_sensitivity: 0.9347 - final_output2_specificity: 0.9987 - val_loss: 0.8451 - val_final_output1_loss: 0.5520 - val_final_output2_loss: 0.2930 - val_final_output1_dice_coef: 0.7424 - val_final_output1_iou: 0.5909 - val_final_output1_sensitivity: 0.6691 - val_final_output1_specificity: 0.9783 - val_final_output2_dice_coef: 0.8852 - val_final_output2_iou: 0.8059 - val_final_output2_sensitivity: 0.8510 - val_final_output2_specificity: 0.9980
# Epoch 289/300
# 40/40 [==============================] - ETA: 0s - loss: 0.6894 - final_output1_loss: 0.5604 - final_output2_loss: 0.1290 - final_output1_dice_coef: 0.7394 - final_output1_iou: 0.5874 - final_output1_sensitivity: 0.6732 - final_output1_specificity: 0.9767 - final_output2_dice_coef: 0.9507 - final_output2_iou: 0.9072 - final_output2_sensitivity: 0.9407 - final_output2_specificity: 0.9987
# Epoch 289: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 125ms/step - loss: 0.6894 - final_output1_loss: 0.5604 - final_output2_loss: 0.1290 - final_output1_dice_coef: 0.7394 - final_output1_iou: 0.5874 - final_output1_sensitivity: 0.6732 - final_output1_specificity: 0.9767 - final_output2_dice_coef: 0.9507 - final_output2_iou: 0.9072 - final_output2_sensitivity: 0.9407 - final_output2_specificity: 0.9987 - val_loss: 0.8528 - val_final_output1_loss: 0.5576 - val_final_output2_loss: 0.2951 - val_final_output1_dice_coef: 0.7404 - val_final_output1_iou: 0.5884 - val_final_output1_sensitivity: 0.6781 - val_final_output1_specificity: 0.9768 - val_final_output2_dice_coef: 0.8839 - val_final_output2_iou: 0.8037 - val_final_output2_sensitivity: 0.8518 - val_final_output2_specificity: 0.9978
# Epoch 290/300
# 40/40 [==============================] - ETA: 0s - loss: 0.6977 - final_output1_loss: 0.5637 - final_output2_loss: 0.1340 - final_output1_dice_coef: 0.7380 - final_output1_iou: 0.5859 - final_output1_sensitivity: 0.6717 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9486 - final_output2_iou: 0.9041 - final_output2_sensitivity: 0.9362 - final_output2_specificity: 0.9987
# Epoch 290: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 125ms/step - loss: 0.6977 - final_output1_loss: 0.5637 - final_output2_loss: 0.1340 - final_output1_dice_coef: 0.7380 - final_output1_iou: 0.5859 - final_output1_sensitivity: 0.6717 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9486 - final_output2_iou: 0.9041 - final_output2_sensitivity: 0.9362 - final_output2_specificity: 0.9987 - val_loss: 0.8871 - val_final_output1_loss: 0.5675 - val_final_output2_loss: 0.3196 - val_final_output1_dice_coef: 0.7348 - val_final_output1_iou: 0.5814 - val_final_output1_sensitivity: 0.6496 - val_final_output1_specificity: 0.9798 - val_final_output2_dice_coef: 0.8742 - val_final_output2_iou: 0.7885 - val_final_output2_sensitivity: 0.8340 - val_final_output2_specificity: 0.9979
# Epoch 291/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7072 - final_output1_loss: 0.5670 - final_output2_loss: 0.1401 - final_output1_dice_coef: 0.7365 - final_output1_iou: 0.5837 - final_output1_sensitivity: 0.6705 - final_output1_specificity: 0.9764 - final_output2_dice_coef: 0.9461 - final_output2_iou: 0.9002 - final_output2_sensitivity: 0.9333 - final_output2_specificity: 0.9987
# Epoch 291: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7072 - final_output1_loss: 0.5670 - final_output2_loss: 0.1401 - final_output1_dice_coef: 0.7365 - final_output1_iou: 0.5837 - final_output1_sensitivity: 0.6705 - final_output1_specificity: 0.9764 - final_output2_dice_coef: 0.9461 - final_output2_iou: 0.9002 - final_output2_sensitivity: 0.9333 - final_output2_specificity: 0.9987 - val_loss: 0.8633 - val_final_output1_loss: 0.5662 - val_final_output2_loss: 0.2971 - val_final_output1_dice_coef: 0.7389 - val_final_output1_iou: 0.5865 - val_final_output1_sensitivity: 0.7141 - val_final_output1_specificity: 0.9699 - val_final_output2_dice_coef: 0.8835 - val_final_output2_iou: 0.8031 - val_final_output2_sensitivity: 0.8440 - val_final_output2_specificity: 0.9981
# Epoch 292/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7020 - final_output1_loss: 0.5648 - final_output2_loss: 0.1372 - final_output1_dice_coef: 0.7377 - final_output1_iou: 0.5854 - final_output1_sensitivity: 0.6735 - final_output1_specificity: 0.9763 - final_output2_dice_coef: 0.9474 - final_output2_iou: 0.9019 - final_output2_sensitivity: 0.9355 - final_output2_specificity: 0.9987
# Epoch 292: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.7020 - final_output1_loss: 0.5648 - final_output2_loss: 0.1372 - final_output1_dice_coef: 0.7377 - final_output1_iou: 0.5854 - final_output1_sensitivity: 0.6735 - final_output1_specificity: 0.9763 - final_output2_dice_coef: 0.9474 - final_output2_iou: 0.9019 - final_output2_sensitivity: 0.9355 - final_output2_specificity: 0.9987 - val_loss: 0.8614 - val_final_output1_loss: 0.5545 - val_final_output2_loss: 0.3069 - val_final_output1_dice_coef: 0.7415 - val_final_output1_iou: 0.5897 - val_final_output1_sensitivity: 0.6699 - val_final_output1_specificity: 0.9778 - val_final_output2_dice_coef: 0.8796 - val_final_output2_iou: 0.7970 - val_final_output2_sensitivity: 0.8295 - val_final_output2_specificity: 0.9985
# Epoch 293/300
# 40/40 [==============================] - ETA: 0s - loss: 0.6999 - final_output1_loss: 0.5607 - final_output2_loss: 0.1392 - final_output1_dice_coef: 0.7396 - final_output1_iou: 0.5877 - final_output1_sensitivity: 0.6746 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9465 - final_output2_iou: 0.9011 - final_output2_sensitivity: 0.9345 - final_output2_specificity: 0.9986
# Epoch 293: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.6999 - final_output1_loss: 0.5607 - final_output2_loss: 0.1392 - final_output1_dice_coef: 0.7396 - final_output1_iou: 0.5877 - final_output1_sensitivity: 0.6746 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9465 - final_output2_iou: 0.9011 - final_output2_sensitivity: 0.9345 - final_output2_specificity: 0.9986 - val_loss: 0.9287 - val_final_output1_loss: 0.5869 - val_final_output2_loss: 0.3417 - val_final_output1_dice_coef: 0.7262 - val_final_output1_iou: 0.5709 - val_final_output1_sensitivity: 0.6326 - val_final_output1_specificity: 0.9827 - val_final_output2_dice_coef: 0.8646 - val_final_output2_iou: 0.7749 - val_final_output2_sensitivity: 0.8461 - val_final_output2_specificity: 0.9969
# Epoch 294/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7146 - final_output1_loss: 0.5715 - final_output2_loss: 0.1432 - final_output1_dice_coef: 0.7353 - final_output1_iou: 0.5821 - final_output1_sensitivity: 0.6719 - final_output1_specificity: 0.9761 - final_output2_dice_coef: 0.9453 - final_output2_iou: 0.8979 - final_output2_sensitivity: 0.9330 - final_output2_specificity: 0.9986
# Epoch 294: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7146 - final_output1_loss: 0.5715 - final_output2_loss: 0.1432 - final_output1_dice_coef: 0.7353 - final_output1_iou: 0.5821 - final_output1_sensitivity: 0.6719 - final_output1_specificity: 0.9761 - final_output2_dice_coef: 0.9453 - final_output2_iou: 0.8979 - final_output2_sensitivity: 0.9330 - final_output2_specificity: 0.9986 - val_loss: 0.8898 - val_final_output1_loss: 0.5716 - val_final_output2_loss: 0.3182 - val_final_output1_dice_coef: 0.7364 - val_final_output1_iou: 0.5832 - val_final_output1_sensitivity: 0.7055 - val_final_output1_specificity: 0.9729 - val_final_output2_dice_coef: 0.8739 - val_final_output2_iou: 0.7892 - val_final_output2_sensitivity: 0.8629 - val_final_output2_specificity: 0.9967
# Epoch 295/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7044 - final_output1_loss: 0.5672 - final_output2_loss: 0.1371 - final_output1_dice_coef: 0.7365 - final_output1_iou: 0.5838 - final_output1_sensitivity: 0.6703 - final_output1_specificity: 0.9764 - final_output2_dice_coef: 0.9474 - final_output2_iou: 0.9019 - final_output2_sensitivity: 0.9354 - final_output2_specificity: 0.9986
# Epoch 295: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7044 - final_output1_loss: 0.5672 - final_output2_loss: 0.1371 - final_output1_dice_coef: 0.7365 - final_output1_iou: 0.5838 - final_output1_sensitivity: 0.6703 - final_output1_specificity: 0.9764 - final_output2_dice_coef: 0.9474 - final_output2_iou: 0.9019 - final_output2_sensitivity: 0.9354 - final_output2_specificity: 0.9986 - val_loss: 0.8878 - val_final_output1_loss: 0.5559 - val_final_output2_loss: 0.3320 - val_final_output1_dice_coef: 0.7423 - val_final_output1_iou: 0.5909 - val_final_output1_sensitivity: 0.6959 - val_final_output1_specificity: 0.9748 - val_final_output2_dice_coef: 0.8688 - val_final_output2_iou: 0.7811 - val_final_output2_sensitivity: 0.8581 - val_final_output2_specificity: 0.9968
# Epoch 296/300
# 40/40 [==============================] - ETA: 0s - loss: 0.6992 - final_output1_loss: 0.5620 - final_output2_loss: 0.1372 - final_output1_dice_coef: 0.7389 - final_output1_iou: 0.5871 - final_output1_sensitivity: 0.6733 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9472 - final_output2_iou: 0.9024 - final_output2_sensitivity: 0.9368 - final_output2_specificity: 0.9986
# Epoch 296: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.6992 - final_output1_loss: 0.5620 - final_output2_loss: 0.1372 - final_output1_dice_coef: 0.7389 - final_output1_iou: 0.5871 - final_output1_sensitivity: 0.6733 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9472 - final_output2_iou: 0.9024 - final_output2_sensitivity: 0.9368 - final_output2_specificity: 0.9986 - val_loss: 0.8677 - val_final_output1_loss: 0.5558 - val_final_output2_loss: 0.3120 - val_final_output1_dice_coef: 0.7407 - val_final_output1_iou: 0.5888 - val_final_output1_sensitivity: 0.6675 - val_final_output1_specificity: 0.9790 - val_final_output2_dice_coef: 0.8777 - val_final_output2_iou: 0.7943 - val_final_output2_sensitivity: 0.8179 - val_final_output2_specificity: 0.9989
# Epoch 297/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7034 - final_output1_loss: 0.5636 - final_output2_loss: 0.1399 - final_output1_dice_coef: 0.7380 - final_output1_iou: 0.5856 - final_output1_sensitivity: 0.6705 - final_output1_specificity: 0.9767 - final_output2_dice_coef: 0.9463 - final_output2_iou: 0.9002 - final_output2_sensitivity: 0.9339 - final_output2_specificity: 0.9986
# Epoch 297: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.7034 - final_output1_loss: 0.5636 - final_output2_loss: 0.1399 - final_output1_dice_coef: 0.7380 - final_output1_iou: 0.5856 - final_output1_sensitivity: 0.6705 - final_output1_specificity: 0.9767 - final_output2_dice_coef: 0.9463 - final_output2_iou: 0.9002 - final_output2_sensitivity: 0.9339 - final_output2_specificity: 0.9986 - val_loss: 0.8742 - val_final_output1_loss: 0.5595 - val_final_output2_loss: 0.3147 - val_final_output1_dice_coef: 0.7393 - val_final_output1_iou: 0.5870 - val_final_output1_sensitivity: 0.6717 - val_final_output1_specificity: 0.9773 - val_final_output2_dice_coef: 0.8766 - val_final_output2_iou: 0.7923 - val_final_output2_sensitivity: 0.8305 - val_final_output2_specificity: 0.9983
# Epoch 298/300
# 40/40 [==============================] - ETA: 0s - loss: 0.6927 - final_output1_loss: 0.5637 - final_output2_loss: 0.1291 - final_output1_dice_coef: 0.7380 - final_output1_iou: 0.5859 - final_output1_sensitivity: 0.6735 - final_output1_specificity: 0.9763 - final_output2_dice_coef: 0.9500 - final_output2_iou: 0.9076 - final_output2_sensitivity: 0.9394 - final_output2_specificity: 0.9987
# Epoch 298: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.6927 - final_output1_loss: 0.5637 - final_output2_loss: 0.1291 - final_output1_dice_coef: 0.7380 - final_output1_iou: 0.5859 - final_output1_sensitivity: 0.6735 - final_output1_specificity: 0.9763 - final_output2_dice_coef: 0.9500 - final_output2_iou: 0.9076 - final_output2_sensitivity: 0.9394 - final_output2_specificity: 0.9987 - val_loss: 0.9026 - val_final_output1_loss: 0.5686 - val_final_output2_loss: 0.3341 - val_final_output1_dice_coef: 0.7365 - val_final_output1_iou: 0.5835 - val_final_output1_sensitivity: 0.6850 - val_final_output1_specificity: 0.9765 - val_final_output2_dice_coef: 0.8683 - val_final_output2_iou: 0.7790 - val_final_output2_sensitivity: 0.8642 - val_final_output2_specificity: 0.9962
# Epoch 299/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7885 - final_output1_loss: 0.5899 - final_output2_loss: 0.1985 - final_output1_dice_coef: 0.7263 - final_output1_iou: 0.5713 - final_output1_sensitivity: 0.6597 - final_output1_specificity: 0.9759 - final_output2_dice_coef: 0.9219 - final_output2_iou: 0.8622 - final_output2_sensitivity: 0.9114 - final_output2_specificity: 0.9980
# Epoch 299: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 125ms/step - loss: 0.7885 - final_output1_loss: 0.5899 - final_output2_loss: 0.1985 - final_output1_dice_coef: 0.7263 - final_output1_iou: 0.5713 - final_output1_sensitivity: 0.6597 - final_output1_specificity: 0.9759 - final_output2_dice_coef: 0.9219 - final_output2_iou: 0.8622 - final_output2_sensitivity: 0.9114 - final_output2_specificity: 0.9980 - val_loss: 0.9227 - val_final_output1_loss: 0.5778 - val_final_output2_loss: 0.3449 - val_final_output1_dice_coef: 0.7323 - val_final_output1_iou: 0.5782 - val_final_output1_sensitivity: 0.6722 - val_final_output1_specificity: 0.9745 - val_final_output2_dice_coef: 0.8630 - val_final_output2_iou: 0.7725 - val_final_output2_sensitivity: 0.8189 - val_final_output2_specificity: 0.9979
# Epoch 300/300
# 40/40 [==============================] - ETA: 0s - loss: 0.7163 - final_output1_loss: 0.5678 - final_output2_loss: 0.1485 - final_output1_dice_coef: 0.7364 - final_output1_iou: 0.5838 - final_output1_sensitivity: 0.6719 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9430 - final_output2_iou: 0.8937 - final_output2_sensitivity: 0.9321 - final_output2_specificity: 0.9984
# Epoch 300: val_loss did not improve from 0.84497
# 40/40 [==============================] - 5s 124ms/step - loss: 0.7163 - final_output1_loss: 0.5678 - final_output2_loss: 0.1485 - final_output1_dice_coef: 0.7364 - final_output1_iou: 0.5838 - final_output1_sensitivity: 0.6719 - final_output1_specificity: 0.9765 - final_output2_dice_coef: 0.9430 - final_output2_iou: 0.8937 - final_output2_sensitivity: 0.9321 - final_output2_specificity: 0.9984 - val_loss: 0.8578 - val_final_output1_loss: 0.5592 - val_final_output2_loss: 0.2986 - val_final_output1_dice_coef: 0.7386 - val_final_output1_iou: 0.5861 - val_final_output1_sensitivity: 0.6568 - val_final_output1_specificity: 0.9795 - val_final_output2_dice_coef: 0.8827 - val_final_output2_iou: 0.8019 - val_final_output2_sensitivity: 0.8417 - val_final_output2_specificity: 0.9980

# %%
def evaluate_metrics(y_test, y_pred):
  n = y_pred.shape[0]
  all_F1_score = np.zeros(n)
  all_dice = np.zeros(n)
  all_jaccard = np.zeros(n)
  all_sensitivity = np.zeros(n)
  all_specificity = np.zeros(n)
  for i in range(n):
      gt, pred = y_test[i], y_pred[i]
      gt_flt = np.ndarray.flatten(gt)
      pred_flt = np.ndarray.flatten(pred)

      precisions, recalls, thresholds = precision_recall_curve(gt_flt, pred_flt)
      f1 = 2*(precisions * recalls) / (precisions + recalls)
      max_value = np.argmax(f1)
      thres = thresholds[max_value]
      pred_mask = (pred_flt >= thres)
      pred_label = pred_mask*1

      tn, fp, fn, tp = confusion_matrix(gt_flt, pred_label).ravel()

      F1_score = tp/(tp+((0.5)*(fp+fn)))
      iou = tp / (tp + fp + fn)
      dice = 2*tp / (2*tp + fp + fn)
      specificity = tn / (tn + fp)
      recall = tp / (tp + fn)

      all_F1_score[i] = F1_score
      all_dice[i] = dice
      all_jaccard[i] = iou
      all_sensitivity[i] = recall
      all_specificity[i] = specificity

  print(' F1_score: {:4f}, Dice: {:4f}, Jaccard: {:4f}, Sensitivity: {:4f}, Specificity: {:4f}'.format(
        np.nanmean(all_F1_score), np.nanmean(all_dice), np.nanmean(all_jaccard), np.nanmean(all_sensitivity), np.nanmean(all_specificity)
  ))
  return all_F1_score, all_dice, all_jaccard, all_sensitivity, all_specificity

# %%
model.save_weights('/content/drive/MyDrive/Colab_Folder/Model Weights/DRIVE/checkpoints/MTLTransfuseep300bs16head4_32.h5')

# %%
# valid_data = '/content/ISIC2018_256x256/test' #data path
X_test, y_test = get_data(valid_data)
# Out:
# Getting and resizing images ...
# Done!

# %%
# Convert ground truth labels to binary
y_test_BV = (y_test[0] > 0.5).astype(np.uint8)
y_test_OD = (y_test[1] > 0.5).astype(np.uint8)

predictions = model.predict(X_test, batch_size=1, verbose=1)
# Out:
# 20/20 [==============================] - 1s 6ms/step

# %%
# Convert model's outputs to binary
predictions_BV = (predictions[0] > 0.5).astype(np.uint8)
predictions_OD = (predictions[1] > 0.5).astype(np.uint8)

# %%
# Evaluate metrics for each task
eval_BV = evaluate_metrics(y_test_BV, predictions_BV)
eval_OD = evaluate_metrics(y_test_OD, predictions_OD)
# Out:
# F1_score: 0.782041, Dice: 0.782041, Jaccard: 0.643138, Sensitivity: 0.823067, Specificity: 0.983910
# F1_score: 0.908472, Dice: 0.908472, Jaccard: 0.838861, Sensitivity: 0.975257, Specificity: 0.996424

# %%
test_image = load_img('/content/drive/MyDrive/Colab_Notebooks/DRIVE_Augmented/DRIVE_BioNet-Augmented/test/images/1.png', target_size=(512, 512))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
print(test_image.shape)
# Scale the pixel values to [0, 1] range
test_image = test_image / 255.

preds_test = model.predict(test_image)
end_time = time.time()
# Out:
# (1, 512, 512, 3)
# 1/1 [==============================] - 1s 625ms/step

# %%
import numpy as np

fig, ax = plt.subplots(nrows=1, ncols=3)
ax[0].imshow((test_image[0]))
ax[0].axis('off')
ax[1].imshow(np.squeeze(preds_test[0]), cmap='gray') # squeeze out unnecessary dimensions
ax[1].axis('off')
ax[2].imshow(np.squeeze(preds_test[1]), cmap='gray')
ax[2].axis('off')

#fig, ax = plt.subplots(nrows=1, ncols=2)
#ax[0].imshow(test_image[0])
#ax[1].imshow(preds_test[0], cmap='gray') # you may need
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["final_output1_dice_coef"], label="dice_coefficient_BV")
plt.plot(results.history["val_final_output1_dice_coef"], label="validation dice_coefficient_BV")
plt.plot(results.history["final_output2_dice_coef"], label="dice_coefficient_OD")
plt.plot(results.history["val_final_output2_dice_coef"], label="validation dice_coefficient_OD")
#plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("dice_coefficient")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["final_output1_iou"], label="Jaccard_BV")
plt.plot(results.history["val_final_output1_iou"], label="validation Jaccard_BV")
plt.plot(results.history["final_output2_iou"], label="Jaccard_OD")
plt.plot(results.history["val_final_output2_iou"], label="validation Jaccard_OD")
#plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Jaccard")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["final_output1_sensitivity"], label="Sensitivity_BV")
plt.plot(results.history["val_final_output1_sensitivity"], label="validation Sensitivity_BV")
plt.plot(results.history["final_output2_sensitivity"], label="sensitivity_OD")
plt.plot(results.history["val_final_output2_sensitivity"], label="validation sensitivity_OD")
#plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("sensitivity")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["final_output1_specificity"], label="Specificity_BV")
plt.plot(results.history["val_final_output1_specificity"], label="validation Specificity_BV")
plt.plot(results.history["final_output2_specificity"], label="specificity_OD")
plt.plot(results.history["val_final_output2_specificity"], label="validation specificity_OD")
#plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Specificity")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["final_output1_loss"], label="Loss_BV")
plt.plot(results.history["val_final_output1_loss"], label="validation Loss_BV")
plt.plot(results.history["final_output2_loss"], label="Loss_OD")
plt.plot(results.history["val_final_output2_loss"], label="validation Loss_OD")
#plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend();

# %%
memory_usage = model.count_params() * 4  # Assuming float32 data type (4 bytes per parameter)
print("Memory Usage: {:.2f} MB".format(memory_usage / 1024 / 1024))  # Divide by 1024 twice to convert from bytes to KB, then KB to MB
# Out:
# Memory Usage: 0.25 MB

# %%
  # !pip install keras-flops
  from keras_flops import get_flops

  flops = get_flops(model)
  print(f"FLOPs: {flops / 10**9:.03} G")
# Out:
# Collecting keras-flops
#   Downloading keras_flops-0.1.2-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /usr/local/lib/python3.10/dist-packages (from keras-flops) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<3.0,>=2.2->keras-flops) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow<3.0,>=2.2->keras-flops) (3.2.2)
# Installing collected packages: keras-flops
# Successfully installed keras-flops-0.1.2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-f8ffdf573821> in <cell line: 2>()
#       1 get_ipython().system('pip install keras-flops')
# ----> 2 from keras_flops import get_flops
#       3
#       4 flops = get_flops(model)
#       5 print(f"FLOPs: {flops / 10**9:.03} G")
#
# /usr/local/lib/python3.10/dist-packages/keras_flops/__init__.py in <module>
# ----> 1 from .flops_calculation import get_flops
#
# /usr/local/lib/python3.10/dist-packages/keras_flops/flops_calculation.py in <module>
#       7 from tensorflow.keras import Sequential, Model
#       8
# ----> 9 import keras_flops.flops_registory
#      10
#      11
#
# /usr/local/lib/python3.10/dist-packages/keras_flops/flops_registory.py in <module>
#      37
#      38 @ops.RegisterStatistics("AddV2", "flops")
# ---> 39 def _flops_add(graph, node):
#      40     """inference is supportted"""
#      41     return _binary_per_element_op_flops(graph, node)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in __call__(self, f)
#    2591   def __call__(self, f):
#    2592     """Registers "f" as the statistics function for "op_type"."""
# -> 2593     _stats_registry.register(f, self._op_type + "," + self._statistic_type)
#    2594     return f
#    2595
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/registry.py in register(self, candidate, name)
#      55     if name in self._registry:
#      56       frame = self._registry[name][_LOCATION_TAG]
# ---> 57       raise KeyError(
#      58           "Registering two %s with name '%s'! "
#      59           "(Previous registration was in %s %s:%d)" %
#
# KeyError: "Registering two statistical functions with name 'AddV2,flops'! (Previous registration was in register /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/registry.py:65)"
